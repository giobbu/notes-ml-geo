# %%
from generate_poisson_ar1 import simulate_poisson_ar1

seed = 42
results_sim = simulate_poisson_ar1(seed=seed)

# %%
import json

print("Simulated Poisson AR(1) Process:")
results_sim.keys()
for k, v in results_sim.items():
    print(f"{k}: {type(v)}, sample: {v[:5] if isinstance(v, list) else v}")
# Out:
# Simulated Poisson AR(1) Process:
# timestamp: <class 'list'>, sample: ['2024-01-01T00:00:00Z', '2024-01-01T01:00:00Z', '2024-01-01T02:00:00Z', '2024-01-01T03:00:00Z', '2024-01-01T04:00:00Z']
# t: <class 'list'>, sample: [0, 1, 2, 3, 4]
# z: <class 'list'>, sample: [1.2796275698990296, 1.3028009741760407, 1.1460238398210036, 1.1247009928371878, 0.771013322524037]
# lam: <class 'list'>, sample: [3.595300478076653, 3.6795886799310367, 3.14566036102661, 3.0792959796972976, 2.161955902799498]
# y: <class 'list'>, sample: [3, 6, 6, 3, 1]
# params: <class 'dict'>, sample: {'n': 300, 'mu': 1.0, 'phi': 0.9, 'sigma_eta': 0.4, 'seed': 42}

# %%
from plot_poisson_ar1 import plot_simulation

plot_simulation(results_sim)
